# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Load CSV file
file = "EmployeeSQL/departments.csv"

# Read the  csv and store into Pandas DataFrame
departments_df = pd.read_csv(file, encoding="utf-8")

departments_df.head(10)
# departments_df.shape
# Out:
#   dept_no           dept_name
# 0    d001           Marketing
# 1    d002             Finance
# 2    d003     Human Resources
# 3    d004          Production
# 4    d005         Development
# 5    d006  Quality Management
# 6    d007               Sales
# 7    d008            Research
# 8    d009    Customer Service

# %%
# Load CSV file
file = "EmployeeSQL/dept_emp.csv"

# Read the  csv and store into Pandas DataFrame
dept_emp_df = pd.read_csv(file, encoding="utf-8")

# dept_emp_df.shape
dept_emp_df.head(20)
# Out:
#     emp_no dept_no
# 0    10001    d005
# 1    10002    d007
# 2    10003    d004
# 3    10004    d004
# 4    10005    d003
# 5    10006    d005
# 6    10007    d008
# 7    10008    d005
# 8    10009    d006
# 9    10010    d004
# 10   10010    d006
# 11   10011    d009
# 12   10012    d005
# 13   10013    d003
# 14   10014    d005
# 15   10015    d008
# 16   10016    d007
# 17   10017    d001
# 18   10018    d004
# 19   10018    d005

# %%
# Load CSV file
file = "EmployeeSQL/dept_manager.csv"

# Read the  csv and store into Pandas DataFrame
dept_manager_df = pd.read_csv(file, encoding="utf-8")

dept_manager_df.head(24)
# dept_manager_df.shape
# Out:
#    dept_no  emp_no
# 0     d001  110022
# 1     d001  110039
# 2     d002  110085
# 3     d002  110114
# 4     d003  110183
# 5     d003  110228
# 6     d004  110303
# 7     d004  110344
# 8     d004  110386
# 9     d004  110420
# 10    d005  110511
# 11    d005  110567
# 12    d006  110725
# 13    d006  110765
# 14    d006  110800
# 15    d006  110854
# 16    d007  111035
# 17    d007  111133
# 18    d008  111400
# 19    d008  111534
# 20    d009  111692
# 21    d009  111784
# 22    d009  111877
# 23    d009  111939

# %%
# Load CSV file
file = "EmployeeSQL/employees.csv"

# Read the  csv and store into Pandas DataFrame
employees_df = pd.read_csv(file, encoding="utf-8")

employees_df.head()
# employees_df.shape
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001   7/25/1953    Hideyuki   Zallocco   M   4/28/1990
# 1  475053        e0002  11/18/1954       Byong  Delgrande   F    9/7/1991
# 2   57444        e0002   1/30/1958       Berry       Babb   F   3/21/1992
# 3  421786        s0001   9/28/1957       Xiong   Verhoeff   M  11/26/1987
# 4  282238        e0003  10/28/1952  Abdelkader    Baumann   F   1/18/1991

# %%
# Load CSV file
file = "EmployeeSQL/salaries.csv"

# Read the  csv and store into Pandas DataFrame
salaries_df = pd.read_csv(file, encoding="utf-8")

salaries_df.head()
# salaries_df.shape
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
# Load CSV file
file = "EmployeeSQL/titles.csv"

# Read the  csv and store into Pandas DataFrame
titles_df = pd.read_csv(file, encoding="utf-8")

titles_df.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.2.tar.gz (380 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/keithmoravec/opt/anaconda3/bin/python -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/08/k5qj0k9j1dbgppb_7vzc5rnm0000gn/T/pip-install-fwtm89vv/psycopg2_eaa1f77c85d5405d8f359c963d957248/setup.py'"'"'; __file__='"'"'/private/var/folders/08/k5qj0k9j1dbgppb_7vzc5rnm0000gn/T/pip-install-fwtm89vv/psycopg2_eaa1f77c85d5405d8f359c963d957248/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/08/k5qj0k9j1dbgppb_7vzc5rnm0000gn/T/pip-pip-egg-info-o9po3xe1
#          cwd: /private/var/folders/08/k5qj0k9j1dbgppb_7vzc5rnm0000gn/T/pip-install-fwtm89vv/psycopg2_eaa1f77c85d5405d8f359c963d957248/
#     Complete output (23 lines):
#     running egg_info
# ...

# %%
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-7d2da0a5d979> in <module>
# ----> 1 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
# Create engine using the `SQL_Homework` database file

engine = create_engine('postgresql://localhost:5432/SQL_Homework')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-2a94e816343d> in <module>
#       1 # Create engine using the `SQL_Homework` database file
#       2
# ----> 3 engine = create_engine('postgresql://localhost:5432/SQL_Homework')
#       4 connection = engine.connect()
#
# <string> in create_engine(url, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     546             if k in kwargs:
#     547                 dbapi_args[k] = pop_kwarg(k)
# ...
